# %% [markdown]
# # This script contains the following points:
#
# #### 01. Import libraries
#
# #### 02. Import data set
#
# #### 03. Grouping Data with pandas
#
# #### Step 1 Split the data into groups based on some criteria
# #### Step 2 Apply a function to each group separately.
# #### Step 3 Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.
#
# Aggregating Data with agg() function
#
# Aggregating Data with transform() function
#
# Deriving Columns with loc() function

# %% [markdown]
# # 01. Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data set

# %%
# Set path

path = r'C:\Users\nang6\OneDrive\Bureau\Data Analytics\Data Immersion\Achievement 4\02-2020 Instacart Basket Analysis'

# %%
# Import orders_products_merged_2

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %% [markdown]
# # 03. Grouping Data with pandas

# %%
# Create a subest 

df = ords_prods_merge[:1000000]

# %%
# Check size

df.shape
# Out:
# (1000000, 18)

# %%
# Check first 10 rows

df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %% [markdown]
# # Groupby() function

# %%
# Step 1 - Split the data into groups based on some criteria

df.groupby('product_name')

# %% [markdown]
# # Aggregating Data with agg() function

# %% [markdown]
# 1. Performing a Single Aggregation

# %%
# Apply agg() function to each group separately (here it gives the average number of orders per department_id)

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# We can also use the below function to achieve the same results:

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# 2. Performing Multiple Aggregations

# %%
# Produce mean, min and max

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregating Data with transform() function

# %%
# Step 3 - Create a new column, “max_order,” and place the results of the aggregation

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check outcome

ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# Other way to check outcome

ords_prods_merge.head(100)

# %%
# This command tells pandas not to assign any options regarding the maximum number of rows to display

pd.options.display.max_rows = None

# %%
# Check outcome again
ords_prods_merge.head(100)

# %% [markdown]
# # Deriving Columns with loc() function

# %%
# Create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Print the frequency of the new “loyalty_flag” column

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check outcome

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
